# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')

print(df.to_string)
# Out:
# <bound method DataFrame.to_string of                                                    title             type  \
# 0      کمیک ددپول                                    ...        کتاب صوتی
# 1      میکروبوک تسخیر قلب‌ها در کمتر از ۹۰  ثانیه    ...        کتاب صوتی
# 2      اقتصاد خرد ۲                                  ...        کتاب صوتی
# 3                                          هنر برنده شدن  کتاب الکترونیکی
# 4                                             غروب بت‌ها        کتاب صوتی
# ...                                                  ...              ...
# 22041  مغز با شخصیت                                  ...  کتاب الکترونیکی
# 22042  مجله چشمه‌خوان - شماره ۶                      ...        کتاب صوتی
# 22043  داستان شگفت‌انگیز کوانتوم                     ...        کتاب صوتی
# 22044  استاندارد خدماتخانه عمومی برای کودکان و نوجوان...        کتاب صوتی
# 22045                                         اشد ملاقات  کتاب الکترونیکی
#
# ...
